# %%
# !pip install requests pandas matplotlib seaborn scikit-learn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\adomas\appdata\roaming\python\python313\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\adomas\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\adomas\appdata\roaming\python\python313\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\adomas\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\adomas\appdata\roaming\python\python313\site-packages (1.7.0)
# Requirement already satisfied: numpy in c:\users\adomas\appdata\roaming\python\python313\site-packages (2.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\adomas\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import datetime as dt
import itertools
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from order_book import order_book_features
from order_book import fetch_sell_orders

# %%
ITEMS   = ["T4_BAG", "T5_BAG", "T4_CAPE", "T5_CAPE", "T4_HEAD_PLATE_SET1",
           "T5_HEAD_PLATE_SET1", "T4_2H_AXE", "T5_2H_AXE", "T4_2H_BOW", "T5_2H_BOW"]
CITIES  = ["Caerleon", "Bridgewatch", "Lymhurst", "Fort Sterling", "Martlock"]
URL     = "https://west.albion-online-data.com/api/v2/stats/history/{}.json"

today   = dt.date.today()
start   = today - dt.timedelta(days=30)

def fetch_history(item):
    params = {
        "date": start.isoformat(),
        "end_date": today.isoformat(),
        "locations": ",".join(CITIES),
        "time-scale": 24,                 # daily granularity
        "qualities": 1                    # normal quality only
    }
    return requests.get(URL.format(item), params=params).json()

raw = {item: fetch_history(item) for item in ITEMS}

print(raw)
# Out:
# {'T4_BAG': [{'location': 'Bridgewatch', 'item_id': 'T4_BAG', 'quality': 1, 'data': [{'item_count': 45, 'avg_price': 2775, 'timestamp': '2025-07-19T04:00:00'}, {'item_count': 62, 'avg_price': 2872, 'timestamp': '2025-07-19T05:00:00'}, {'item_count': 21, 'avg_price': 2848, 'timestamp': '2025-07-19T06:00:00'}, {'item_count': 28, 'avg_price': 2825, 'timestamp': '2025-07-19T07:00:00'}, {'item_count': 10, 'avg_price': 2844, 'timestamp': '2025-07-19T08:00:00'}, {'item_count': 13, 'avg_price': 2729, 'timestamp': '2025-07-19T09:00:00'}, {'item_count': 4, 'avg_price': 3010, 'timestamp': '2025-07-19T10:00:00'}, {'item_count': 16, 'avg_price': 2765, 'timestamp': '2025-07-19T11:00:00'}, {'item_count': 32, 'avg_price': 2755, 'timestamp': '2025-07-19T12:00:00'}, {'item_count': 34, 'avg_price': 2846, 'timestamp': '2025-07-19T13:00:00'}, {'item_count': 43, 'avg_price': 2705, 'timestamp': '2025-07-19T14:00:00'}, {'item_count': 35, 'avg_price': 2851, 'timestamp': '2025-07-19T15:00:00'}, {'item_count': 225, 'avg_price': 3019, 'timestamp': '2025-07-19T16:00:00'}, {'item_count': 50, 'avg_price': 2761, 'timestamp': '2025-07-19T17:00:00'}, {'item_count': 76, 'avg_price': 2983, 'timestamp': '2025-07-19T18:00:00'}, {'item_count': 73, 'avg_price': 3077, 'timestamp': '2025-07-19T19:00:00'}, {'item_count': 48, 'avg_price': 2974, 'timestamp': '2025-07-19T20:00:00'}, {'item_count': 36, 'avg_price': 3513, 'timestamp': '2025-07-19T21:00:00'}, {'item_count': 32, 'avg_price': 3568, 'timestamp': '2025-07-19T22:00:00'}, {'item_count': 46, 'avg_price': 3797, 'timestamp': '2025-07-19T23:00:00'}, {'item_count': 60, 'avg_price': 3042, 'timestamp': '2025-07-20T00:00:00'}, {'item_count': 58, 'avg_price': 3162, 'timestamp': '2025-07-20T01:00:00'}, {'item_count': 43, 'avg_price': 4424, 'timestamp': '2025-07-20T02:00:00'}, {'item_count': 25, 'avg_price': 7028, 'timestamp': '2025-07-20T03:00:00'}, {'item_count': 43, 'avg_price': 4689, 'timestamp': '2025-07-20T04:00:00'}, {'item_count': 30, 'avg_price': 3291, 'timestamp': '2025-07-20T05:00:00'}, {'item_count': 21, 'avg_price': 3120, 'timestamp': '2025-07-20T06:00:00'}, {'item_count': 27, 'avg_price': 2950, 'timestamp': '2025-07-20T07:00:00'}, {'item_count': 15, 'avg_price': 3163, 'timestamp': '2025-07-20T08:00:00'}, {'item_count': 17, 'avg_price': 3057, 'timestamp': '2025-07-20T09:00:00'}, {'item_count': 8, 'avg_price': 3327, 'timestamp': '2025-07-20T10:00:00'}, {'item_count': 17, 'avg_price': 3278, 'timestamp': '2025-07-20T11:00:00'}, {'item_count': 29, 'avg_price': 2772, 'timestamp': '2025-07-20T12:00:00'}, {'item_count': 43, 'avg_price': 3487, 'timestamp': '2025-07-20T13:00:00'}, {'item_count': 42, 'avg_price': 3484, 'timestamp': '2025-07-20T14:00:00'}, {'item_count': 48, 'avg_price': 3430, 'timestamp': '2025-07-20T15:00:00'}, {'item_count': 39, 'avg_price': 3399, 'timestamp': '2025-07-20T16:00:00'}, {'item_count': 30, 'avg_price': 7686, 'timestamp': '2025-07-20T17:00:00'}, {'item_count': 51, 'avg_price': 3889, 'timestamp': '2025-07-20T18:00:00'}, {'item_count': 19, 'avg_price': 6852, 'timestamp': '2025-07-20T19:00:00'}, {'item_count': 54, 'avg_price': 5781, 'timestamp': '2025-07-20T20:00:00'}, {'item_count': 35, 'avg_price': 18138, 'timestamp': '2025-07-20T22:00:00'}, {'item_count': 53, 'avg_price': 4632, 'timestamp': '2025-07-20T23:00:00'}, {'item_count': 85, 'avg_price': 3901, 'timestamp': '2025-07-21T00:00:00'}, {'item_count': 116, 'avg_price': 3918, 'timestamp': '2025-07-21T01:00:00'}, {'item_count': 45, 'avg_price': 3689, 'timestamp': '2025-07-21T02:00:00'}, {'item_count': 48, 'avg_price': 3660, 'timestamp': '2025-07-21T03:00:00'}, {'item_count': 49, 'avg_price': 3523, 'timestamp': '2025-07-21T04:00:00'}, {'item_count': 38, 'avg_price': 3508, 'timestamp': '2025-07-21T05:00:00'}, {'item_count': 29, 'avg_price': 3211, 'timestamp': '2025-07-21T06:00:00'}, {'item_count': 17, 'avg_price': 3589, 'timestamp': '2025-07-21T07:00:00'}, {'item_count': 15, 'avg_price': 3169, 'timestamp': '2025-07-21T08:00:00'}, {'item_count':  ...

# %%
records = []
for item, data in raw.items():
    for entry in data:
        for daily_data in entry["data"]:
            records.append({
                "item": item,
                "city": entry["location"],
                "timestamp": pd.to_datetime(daily_data["timestamp"]),
                "price": daily_data["avg_price"]
            })
df = pd.DataFrame(records).sort_values(["item", "city", "timestamp"])
df["log_price"] = np.log(df["price"])

display(df.head())
# Out:
#            item         city           timestamp  price  log_price
# 1941  T4_2H_AXE  Bridgewatch 2025-07-18 20:00:00   3007   8.008698
# 1942  T4_2H_AXE  Bridgewatch 2025-07-18 21:00:00   5073   8.531688
# 1943  T4_2H_AXE  Bridgewatch 2025-07-18 22:00:00   5983   8.696677
# 1944  T4_2H_AXE  Bridgewatch 2025-07-18 23:00:00   5984   8.696845
# 1945  T4_2H_AXE  Bridgewatch 2025-07-19 00:00:00   2345   7.760041

# %%
def rolling_z(series, window=7):
    roll = series.rolling(window, min_periods=3)
    return (series - roll.mean()) / roll.std()

df["z"] = df.groupby(["item", "city"])["log_price"].transform(rolling_z)

display(df.head())
# Out:
#            item         city           timestamp  price  log_price         z
# 1941  T4_2H_AXE  Bridgewatch 2025-07-18 20:00:00   3007   8.008698       NaN
# 1942  T4_2H_AXE  Bridgewatch 2025-07-18 21:00:00   5073   8.531688       NaN
# 1943  T4_2H_AXE  Bridgewatch 2025-07-18 22:00:00   5983   8.696677  0.791593
# 1944  T4_2H_AXE  Bridgewatch 2025-07-18 23:00:00   5984   8.696845  0.654613
# 1945  T4_2H_AXE  Bridgewatch 2025-07-19 00:00:00   2345   7.760041 -1.347927

# %%
df["tier"] = df["item"].str.extract(r"T(\d)")[0].astype(int)
df["slot"] = df["item"].str.split("_").str[2]

peer_median = df.groupby(["timestamp", "tier", "slot"])["log_price"].transform("median")
df["peer_dev"] = df["log_price"] - peer_median

# %%
df["abs_z"]        = df["z"].abs()
df["abs_peer_dev"] = df["peer_dev"].abs()

X = df[["abs_z", "abs_peer_dev"]].fillna(0)

iso = IsolationForest(contamination=0.01, random_state=42)
df["manipulated"] = iso.fit_predict(X) == -1

# %%
print(df["manipulated"].value_counts())
# True  -> number of predictions = 1
# False -> everything else
# Out:
# manipulated
# False    2325
# True       24
# Name: count, dtype: int64

# %%
display(df.loc[df['manipulated']==True])
# Out:
#                     item           city           timestamp  price  log_price  \
# 1959           T4_2H_AXE       Caerleon 2025-07-23 02:00:00  34193  10.439776
# 1969           T4_2H_AXE       Caerleon 2025-07-23 18:00:00  34200  10.439981
# 1972           T4_2H_AXE       Caerleon 2025-07-23 22:00:00  18713   9.836974
# 2012           T4_2H_AXE  Fort Sterling 2025-07-23 02:00:00   4203   8.343554
# 2021           T4_2H_AXE  Fort Sterling 2025-07-23 18:00:00   3936   8.277920
# 2025           T4_2H_AXE  Fort Sterling 2025-07-23 22:00:00   3111   8.042699
# 1592  T4_HEAD_PLATE_SET1       Caerleon 2025-07-20 18:00:00   2245   7.716461
# 1593  T4_HEAD_PLATE_SET1       Caerleon 2025-07-20 19:00:00   3324   8.108924
# 1595  T4_HEAD_PLATE_SET1       Caerleon 2025-07-20 21:00:00   3333   8.111628
# 1596  T4_HEAD_PLATE_SET1       Caerleon 2025-07-20 22:00:00     87   4.465908
# 1597  T4_HEAD_PLATE_SET1       Caerleon 2025-07-20 23:00:00     87   4.465908
# 1600  T4_HEAD_PLATE_SET1       Caerleon 2025-07-21 02:00:00   3322   8.108322
# 1603  T4_HEAD_PLATE_SET1       Caerleon 2025-07-21 07:00:00     85   4.442651
# 1605  T4_HEAD_PLATE_SET1       Caerleon 2025-07-21 11:00:00   3498   8.159947
# 1606  T4_HEAD_PLATE_SET1       Caerleon 2025-07-21 12:00:00     88   4.477337
# 1608  T4_HEAD_PLATE_SET1       Caerleon 2025-07-21 15:00:00   3497   8.159661
# 1614  T4_HEAD_PLATE_SET1       Caerleon 2025-07-23 21:00:00   2489   7.819636
# 1622  T4_HEAD_PLATE_SET1       Caerleon 2025-07-24 06:00:00   3501   8.160804
# 1781  T4_HEAD_PLATE_SET1       Martlock 2025-07-24 06:00:00    701   6.552508
# 1812  T5_HEAD_PLATE_SET1    Bridgewatch 2025-07-23 02:00:00    685   6.529419
# 1818  T5_HEAD_PLATE_SET1    Bridgewatch 2025-07-23 09:00:00    704   6.556778
# 1825  T5_HEAD_PLATE_SET1    Bridgewatch 2025-07-23 18:00:00    715   6.572283
# 1829  T5_HEAD_PLATE_SET1    Bridgewatch 2025-07-23 22:00:00    723   6.583409
# 1832  T5_HEAD_PLATE_SET1       Caerleon 2025-07-23 19:00:00   9925   9.202812
#
#              z  tier   slot  peer_dev     abs_z  abs_peer_dev  manipulated
# 1959       NaN     4    AXE  1.048111       NaN      1.048111         True
# 1969  0.373645     4    AXE  1.081030  0.373645      1.081030         True
# 1972 -0.111804     4    AXE  0.897137  0.111804      0.897137         True
# 2012 -0.196991     4    AXE -1.048111  0.196991      1.048111         True
# 2021 -1.884345     4    AXE -1.081030  1.884345      1.081030         True
# 2025 -1.213764     4    AXE -0.897137  1.213764      0.897137         True
# 1592       NaN     4  PLATE  0.782064       NaN      0.782064         True
# 1593  0.577350     4  PLATE  1.081610  0.577350      1.081610         True
# 1595  0.458738     4  PLATE  1.060639  0.458738      1.060639         True
# 1596 -2.029429     4  PLATE -2.347536  2.029429      2.347536         True
# 1597 -1.458891     4  PLATE -2.377842  1.458891      2.377842         True
# 1600  0.703838     4  PLATE  1.085454  0.703838      1.085454         True
# 1603 -1.456320     4  PLATE -2.376273  1.456320      2.376273         True
# 1605  0.499359     4  PLATE  1.252191  0.499359      1.252191         True
# 1606 -1.449306     4  PLATE -2.317250  1.449306      2.317250         True
# 1608  0.712079     4  PLATE  1.236032  0.712079      1.236032         True
# 1614  0.122515     4  PLATE  0.833994  0.122515      0.833994         True
# 1622  1.642416     4  PLATE  0.804148  1.642416      0.804148         True
# 1781 -1.579514     4  PLATE -0.804148  1.579514      0.804148         True
# 1812 -1.912925     5  PLATE -0.857063  1.912925      0.857063         True
# 1818 -1.428773     5  PLATE -1.706039  1.428773      1.706039         True
# 1825 -2.089699     5  PLATE -1.650808  2.089699      1.650808         True
# 1829 -1.308980     5  PLATE -1.712392  1.308980      1.712392         True
# 1832       NaN     5  PLATE  0.738621       NaN      0.738621         True

# %%
# Show the peer median for the same days
peer = (df[(df["tier"]==4)&(df["slot"]=="AXE")]
          .groupby("timestamp")["log_price"]
          .median())

# Compare
suspicious = df[df["manipulated"]]
for ts in suspicious["timestamp"].unique():
    print(ts, "peer median:", peer[ts], "axe price:",
          suspicious.loc[suspicious["timestamp"]==ts, "log_price"].values)
# Out:
# 2025-07-23 02:00:00 peer median: 9.391665029371882 axe price: [10.43977622  8.34355384  6.52941884]
# 2025-07-23 18:00:00 peer median: 9.35895059061142 axe price: [10.43998092  8.27792026  6.57228254]
# 2025-07-23 22:00:00 peer median: 8.939836622687713 axe price: [9.83697375 8.0426995  6.58340922]
# 2025-07-20 18:00:00 peer median: 8.61122983334262 axe price: [7.7164608]
# 2025-07-20 19:00:00 peer median: 8.332308352219117 axe price: [8.10892416]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1753045200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2025-07-20 21:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\datetimes.py:630, in DatetimeIndex.get_loc(self, key)
#     629 try:
# --> 630     return Index.get_loc(self, key)
#     631 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: Timestamp('2025-07-20 21:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 9
#       7 suspicious = df[df["manipulated"]]
#       8 for ts in suspicious["timestamp"].unique():
# ----> 9     print(ts, "peer median:", peer[ts], "axe price:",
#      10           suspicious.loc[suspicious["timestamp"]==ts, "log_price"].values)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\datetimes.py:632, in DatetimeIndex.get_loc(self, key)
#     630     return Index.get_loc(self, key)
#     631 except KeyError as err:
# --> 632     raise KeyError(orig_key) from err
#
# KeyError: Timestamp('2025-07-20 21:00:00')

# %%
ORDERS_URL = "https://west.albion-online-data.com/api/v2/stats/orders/{}.json"

# Example: today's Caerleon T4_2H_AXE sell orders
sell_df = fetch_sell_orders("T4_2H_AXE", "Caerleon")

# %%
ob_feat = order_book_features(sell_df)

# %%
# Build a small cache so we don’t hammer the API
order_cache = {}

def get_ob_features(item, city, date):
    key = (item, city, date.date())
    if key in order_cache:
        return order_cache[key]
    sells = fetch_sell_orders(item, city)
    feats = order_book_features(sells)
    order_cache[key] = feats
    return feats

# vectorised assignment
df = df.sort_values(["item", "city", "timestamp"])
new_cols = df.apply(
    lambda r: pd.Series(get_ob_features(r["item"], r["city"], r["timestamp"])),
    axis=1
)
df = pd.concat([df, new_cols], axis=1)

# %%
X = df[["abs_z", "abs_peer_dev",
        "wall_thickness", "wall_concentration"]].fillna(0)

iso = IsolationForest(contamination=0.01, random_state=42)
df["manipulated_v2"] = iso.fit_predict(X) == -1

# %%
# How many new flags?
print(df["manipulated_v2"].value_counts())

# Inspect
display(df[df["manipulated_v2"]]
        [["item","city","timestamp","price",
          "wall_thickness","wall_concentration"]])
# Out:
# manipulated_v2
# False    1212
# True       13
# Name: count, dtype: int64
#                    item      city  timestamp  price  wall_thickness  \
# 873           T4_2H_AXE  Caerleon 2025-06-24  43693               0
# 874           T4_2H_AXE  Caerleon 2025-06-25  43693               0
# 875           T4_2H_AXE  Caerleon 2025-06-26  43691               0
# 879           T4_2H_AXE  Caerleon 2025-06-30  23353               0
# 881           T4_2H_AXE  Caerleon 2025-07-02  16509               0
# 882           T4_2H_AXE  Caerleon 2025-07-03  22286               0
# 884           T4_2H_AXE  Caerleon 2025-07-05  16176               0
# 886           T4_2H_AXE  Caerleon 2025-07-07  26999               0
# 893           T4_2H_AXE  Caerleon 2025-07-14  34999               0
# 895           T4_2H_AXE  Caerleon 2025-07-16  31465               0
# 898           T4_2H_AXE  Caerleon 2025-07-19  26638               0
# 902           T4_2H_AXE  Caerleon 2025-07-23  29518               0
# 778  T5_HEAD_PLATE_SET1  Caerleon 2025-07-04  11131               0
#
#      wall_concentration
# 873                   0
# 874                   0
# 875                   0
# 879                   0
# 881                   0
# 882                   0
# 884                   0
# 886                   0
# 893                   0
# 895                   0
# 898                   0
# 902                   0
# 778                   0
